# %%
import gmaps
import pandas as pd

# %%
#google developer api key
from config import gkey

#configure gmaps
gmaps.configure(api_key = gkey)

# %%
Crime_DF = pd.DataFrame(pd.read_csv("MCI_2014_to_2018.csv"))

Crime_DF.head()
# Out:
#            X          Y  Index_ event_unique_id            occurrencedate  \
# 0 -79.385193  43.659229    2349  GO-20149004286  2014-06-20T10:55:00.000Z
# 1 -79.425400  43.777592    2350  GO-20142411379  2014-07-02T00:20:00.000Z
# 2 -79.425400  43.777592    2351  GO-20142411379  2014-07-02T00:20:00.000Z
# 3 -79.210373  43.801727    2352  GO-20142412127  2014-07-02T01:30:00.000Z
# 4 -79.254334  43.835884    2354  GO-20142417548  2014-07-02T20:52:00.000Z
#
#                reporteddate premisetype  ucr_code  ucr_ext  \
# 0  2014-06-20T13:20:00.000Z   Apartment      2130      210
# 1  2014-07-02T02:58:00.000Z     Outside      1457      100
# 2  2014-07-02T02:58:00.000Z     Outside      1610      100
# 3  2014-07-02T05:40:00.000Z       House      2120      200
# 4  2014-07-02T20:57:00.000Z  Commercial      1430      100
#
#                offence    ...     occurrencedayofyear occurrencedayofweek  \
# 0           Theft Over    ...                   171.0          Friday
# 1   Pointing A Firearm    ...                   183.0          Wednesday
# 2  Robbery With Weapon    ...                   183.0          Wednesday
# 3                  B&E    ...                   183.0          Wednesday
# 4              Assault    ...                   183.0          Wednesday
#
#    occurrencehour              MCI Division  Hood_ID  \
# 0              10       Theft Over      D52       76
# 1               0          Assault      D32       36
# 2               0          Robbery      D32       36
# 3               1  Break and Enter      D42      132
# 4              20          Assault      D42      130
#
#               Neighbourhood        Lat       Long  ObjectId
# 0  Bay Street Corridor (76)  43.659229 -79.385193      2001
# 1     Newtonbrook West (36)  43.777592 -79.425400      2002
# 2     Newtonbrook West (36)  43.777592 -79.425400      2003
# 3             Malvern (132)  43.801727 -79.210373      2004
# 4            Milliken (130)  43.835884 -79.254334      2005
#
# [5 rows x 29 columns]

# %%
a = Crime_DF["Lat"]
a0 = pd.DataFrame(a)
a0.head()
# Out:
#          Lat
# 0  43.659229
# 1  43.777592
# 2  43.777592
# 3  43.801727
# 4  43.835884

# %%
b = Crime_DF["Long"]
b0 = pd.DataFrame(b)
b0.head()
# Out:
#         Long
# 0 -79.385193
# 1 -79.425400
# 2 -79.425400
# 3 -79.210373
# 4 -79.254334

# %%
result = pd.merge(a0, b0, right_index=True, left_index=True)
result.head()
# Out:
#          Lat       Long
# 0  43.659229 -79.385193
# 1  43.777592 -79.425400
# 2  43.777592 -79.425400
# 3  43.801727 -79.210373
# 4  43.835884 -79.254334

# %%
c = Crime_DF["Hood_ID"]
c.head()
# Out:
# 0     76
# 1     36
# 2     36
# 3    132
# 4    130
# Name: Hood_ID, dtype: int64

# %%
c0 = pd.DataFrame(c)
c0.head()
# Out:
#    Hood_ID
# 0       76
# 1       36
# 2       36
# 3      132
# 4      130

# %%
coordinate = pd.merge(result, c0, right_index=True, left_index=True)
coordinate.head()
# Out:
#          Lat       Long  Hood_ID
# 0  43.659229 -79.385193       76
# 1  43.777592 -79.425400       36
# 2  43.777592 -79.425400       36
# 3  43.801727 -79.210373      132
# 4  43.835884 -79.254334      130

# %%
# Crime Analysis by Majior Crime Indicator
#Crime_Analysis = Crime_DF.groupby(['Hood_ID'])
#Count_Offence=Crime_Analysis["event_unique_id"].count()
#Offence_data=pd.DataFrame({"Total Count of Offence":Count_Offence})
#Offence_data



#HOW MANY OFFENCES HAPPENED IN A NEIGHBOURHOOD/HOOD_ID
#convert hood_id into longitude ,lag

# %%
# Store latitude and longitude in locations
#locations = result
#Count of event_unique_id by Hood_id/neighbourhood, weights=count of offence/hood_id

#m = c0.astype(float)

#plot gmap figure
#fig = gmaps.figure()
# Create heat layer
#heat_layer = gmaps.heatmap_layer(locations, weight = m
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)
# Add layer
#fig.add_layer(heat_layer)

# Display figure
#fig
# Out:
#   File "<ipython-input-90-34dfff8fba98>", line 12
#     dissipating=False, max_intensity=10,
#     ^
# IndentationError: unexpected indent

# %%
#plot gmap figure
#fig = gmaps.figure()

# Create heat layer
#heat_layer = gmaps.heatmap_layer(locations,  
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
#fig.add_layer(heat_layer)

# Display figure
#fig
# Out:
#   File "<ipython-input-91-8a61e80c6a58>", line 6
#     dissipating=False, max_intensity=10,
#     ^
# IndentationError: unexpected indent

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinate)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-b85f93deb198> in <module>()
#       1 # Assign the marker layer to a variable
# ----> 2 markers = gmaps.marker_layer(coordinate)
#       3 # Add the layer to the map
#       4 fig.add_layer(markers)
#       5 fig
#
# /anaconda3/lib/python3.6/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     552     """
#     553     marker_options = _marker_layer_options(
# --> 554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# /anaconda3/lib/python3.6/site-packages/gmaps/marker.py in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     313
#     314     marker_options = {
# --> 315         'location': locations_to_list(locations),
#     316         'hover_text': hover_text,
#     317         'label': label
#
# /anaconda3/lib/python3.6/site-packages/gmaps/locations.py in locations_to_list(locations)
#      12         locations_as_list = [
#      13             (latitude, longitude) for (idx, latitude, longitude)
# ---> 14             in location_tuples
#      15         ]
#      16     except AttributeError:
#
# /anaconda3/lib/python3.6/site-packages/gmaps/locations.py in <listcomp>(.0)
#      11         location_tuples = locations.itertuples()  # locations is a dataframe
#      12         locations_as_list = [
# ---> 13             (latitude, longitude) for (idx, latitude, longitude)
#      14             in location_tuples
#      15         ]
#
# ValueError: too many values to unpack (expected 3)
